-- %% [markdown]
-- # SQL Part 3 Studio
--
-- ### Let's practice your SQL quering skills!  For each question, work along in the notebook adding your query and answering the questions.
--
-- ### **DataSet**
--
-- ### <span style="font-size: 14px; font-family: -apple-system, BlinkMacSystemFont, sans-serif;">We will be using the Goodbooks-10k dataset from the exercises in the prep work.&nbsp; Feel free reference your previous notebooks.</span>
--
-- - The dataset can be found here: [goodbooks-10k](https://www.kaggle.com/zygmunt/goodbooks-10k)
-- - You can access the **BooksDB** in the Launchcode server.
--
-- ### **Business Issue**
--
-- You are an employee at a small independet bookstore and you have been tasked to increase sales.  You decide to use the BooksDB to find books and themes to highlight in fun promotions throughout each month / season.  We will be starting with March and then you will have a chance to explore another month of your choosing.  We want to come up with a list of events/ promotions to run each month.  If you are looking for ideas to include in your promotions:
--
-- - [https://www.calendarr.com/united-states/calendar-2022/](https://www.calendarr.com/united-states/calendar-2022/)
-- - [https://www.holidayinsights.com/moreholidays/](https://www.holidayinsights.com/moreholidays/)
--     - Click on a month and it will take you to a more detailed page

-- %% [markdown]
-- ## Part 1:  March - Women's History Month, Dr Seuss Day(3/2), National Pie Day3/14, St Patrick's Day (3/17), Season - Spring

-- %% [markdown]
-- ### **Event 1:** Women's History Month
--
-- Goal: Highlight Popular Womans Authors based on ratings from the Good Reads DB.
--
-- ### **Write a query that returns tag\_id, the number of times each tag\_id is used and the tag\_name.**
--
-- ### Use the GROUP BY and HAVING clause to narrow your focus.
--
-- Try multiple keywords, ie woman vs female (female ended up giving better results)

-- %%
-- Solution
SELECT t.tag_id, t.tag_name, COUNT(bt.tag_id) AS tag_count
FROM BooksDB.dbo.tags AS t
LEFT JOIN BooksDB.dbo.book_tags AS bt
ON t.tag_id = bt.tag_id
WHERE t.tag_name LIKE '%female%'
GROUP BY t.tag_id, t.tag_name
ORDER BY tag_count DESC
-- Out:
-- (35 rows affected)
-- Total execution time: 00:00:00.215
-- <table><tr><th>tag_id</th><th>tag_name</th><th>tag_count</th></tr><tr><td>11643</td><td>female-author</td><td>997</td></tr><tr><td>11644</td><td>female-authors</td><td>721</td></tr><tr><td>11658</td><td>female-protagonist</td><td>171</td></tr><tr><td>11646</td><td>female-detective</td><td>32</td></tr><tr><td>11662</td><td>female-writers</td><td>18</td></tr><tr><td>11642</td><td>female</td><td>17</td></tr><tr><td>11656</td><td>female-pov</td><td>17</td></tr><tr><td>11652</td><td>female-lead</td><td>14</td></tr><tr><td>3514</td><td>author-female</td><td>12</td></tr><tr><td>28834</td><td>strong-female-lead</td><td>10</td></tr><tr><td>11647</td><td>female-detectives</td><td>9</td></tr><tr><td>11650</td><td>female-friendship</td><td>4</td></tr><tr><td>28830</td><td>strong-female</td><td>4</td></tr><tr><td>28833</td><td>strong-female-characters</td><td>3</td></tr><tr><td>11645</td><td>female-biographies</td><td>2</td></tr><tr><td>1741</td><td>afghan-female-entrepreneur-under-ta</td><td>1</td></tr><tr><td>4309</td><td>best-adult-female-friendship-books</td><td>1</td></tr><tr><td>11648</td><td>female-doctor</td><td>1</td></tr><tr><td>11649</td><td>female-fiction</td><td>1</td></tr><tr><td>11651</td><td>female-genre-authors</td><td>1</td></tr><tr><td>11653</td><td>female-main-character</td><td>1</td></tr><tr><td>11654</td><td>female-persuasion</td><td>1</td></tr><tr><td>11655</td><td>female-pi</td><td>1</td></tr><tr><td>11657</td><td>female-povs</td><td>1</td></tr><tr><td>11659</td><td>female-serial-killer</td><td>1</td></tr><tr><td>11660</td><td>female-spy</td><td>1</td></tr><tr><td>11661</td><td>female-writer</td><td>1</td></tr><tr><td>15331</td><td>important-female-authors</td><td>1</td></tr><tr><td>17079</td><td>kick-ass-female</td><td>1</td></tr><tr><td>24455</td><td>protagonist-female</td><td>1</td></tr><tr><td>28831</td><td>strong-female-character</td><td>1</td></tr><tr><td>28832</td><td>strong-female-character-s</td><td>1</td></tr><tr><td>28835</td><td>strong-female-protagonist</td><td>1</td></tr><tr><td>28836</td><td>strong-female-supporting-characters</td><td>1</td></tr><tr><td>29324</td><td>tbr-ax-female</td><td>1</td></tr></table>

-- %% [markdown]
-- ### **Which keyword(s) and tag(s) would you like to explore more?**
--
-- 11646 - female-detective

-- %% [markdown]
-- ### **Write a query to return authors, titles, ratings and** **selected tag(s)\_id.**

-- %%
-- Solution
SELECT b.authors, b.title, b.average_rating, bt.tag_id
FROM BooksDB.dbo.books AS b
INNER JOIN BooksDB.dbo.book_tags AS bt
ON bt.goodreads_book_id = b.best_book_id
WHERE bt.tag_id = 11646
-- Out:
-- (31 rows affected)
-- Total execution time: 00:00:00.389
-- <table><tr><th>authors</th><th>title</th><th>average_rating</th><th>tag_id</th></tr><tr><td>Sue Grafton</td><td>A is for Alibi (Kinsey Millhone, #1)</td><td>3.82</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>M is for Malice (Kinsey Millhone, #13)</td><td>4.07</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>J is for Judgment (Kinsey Millhone, #10)</td><td>4.01</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>K is for Killer (Kinsey Millhone, #11)</td><td>3.98</td><td>11646</td></tr><tr><td>Lisa Gardner</td><td>Love You More (Tessa Leoni, #1; Detective D.D. Warren, #5)</td><td>4.15</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>B is for Burglar  (Kinsey Millhone, #2)</td><td>3.83</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>C is for Corpse  (Kinsey Millhone, #3)</td><td>3.87</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>R is for Ricochet (Kinsey Millhone, #18)</td><td>3.96</td><td>11646</td></tr><tr><td>Tess Gerritsen</td><td>The Keepsake (Rizzoli &amp; Isles, #7)</td><td>4.09</td><td>11646</td></tr><tr><td>Lisa Gardner</td><td>Live to Tell (Detective D.D. Warren, #4)</td><td>4.18</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>N is for Noose (Kinsey Millhone, #14)</td><td>3.97</td><td>11646</td></tr><tr><td>Alan Bradley</td><td>A Red Herring Without Mustard (Flavia de Luce, #3)</td><td>4.07</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>D is for Deadbeat (Kinsey Millhone, #4)</td><td>3.85</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>F is for Fugitive (Kinsey Millhone, #6)</td><td>3.9</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>X (Kinsey Millhone, #24)</td><td>3.88</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>E is for Evidence (Kinsey Millhone, #5)</td><td>3.88</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>G is for Gumshoe (Kinsey Millhone, #7)</td><td>3.9</td><td>11646</td></tr><tr><td>Alexander McCall Smith</td><td>Blue Shoes and Happiness (No. 1 Ladies' Detective Agency, #7)</td><td>4.06</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>H is for Homicide (Kinsey Millhone, #8)</td><td>3.89</td><td>11646</td></tr><tr><td>Lisa Gardner</td><td>Say Goodbye (Quincy &amp; Rainie, #6)</td><td>4.12</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>U Is for Undertow (Kinsey Millhone, #21)</td><td>3.93</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>T is for Trespass (Kinsey Millhone, #20)</td><td>3.91</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>S is for Silence (Kinsey Millhone, #19)</td><td>3.9</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>O is for Outlaw (Kinsey Millhone, #15)</td><td>3.92</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>Q is for Quarry (Kinsey Millhone, #17)</td><td>3.91</td><td>11646</td></tr><tr><td>Alexander McCall Smith</td><td>The Miracle at Speedy Motors (No.1 Ladies' Detective Agency, #9)</td><td>4.09</td><td>11646</td></tr><tr><td>Sue Grafton</td><td>P is for Peril (Kinsey Millhone, #16)</td><td>3.85</td><td>11646</td></tr><tr><td>Jacqueline Winspear</td><td>The Mapping of Love and Death (Maisie Dobbs, #7)</td><td>4.19</td><td>11646</td></tr><tr><td>Alexander McCall Smith</td><td>Tea Time for the Traditionally Built (No. 1 Ladies' Detective Agency, #10)</td><td>4.11</td><td>11646</td></tr><tr><td>Lisa Gardner</td><td>The Next Accident (Quincy &amp; Rainie, #3)</td><td>4.16</td><td>11646</td></tr><tr><td>Sara Paretsky</td><td>Indemnity Only (V.I. Warshawski, #1)</td><td>3.89</td><td>11646</td></tr></table>

-- %% [markdown]
-- ### **Record your thoughts about why you wrote the query the way you did.**

-- %% [markdown]
-- # Part 2: Choose Another Month
--
-- Choose another month and plan at least 2 events / promotions and answer the following questions.
--
-- Which month did you choose?
--
-- What 2 events / promotions are you highlighting?
--
-- > 1.  Valentine's Day
-- > 2.  Adoption

-- %% [markdown]
-- # Part 3: Summarize your Work
--
-- For each event write at least one query that joins any two tables in the BooksDB to support your choice and record you thoughts as to why you used the paticlular query. At least one of your queries needs to include a HAVING clause.

-- %%
-- Event 1 Query
SELECT TOP 100 t.tag_id, t.tag_name, COUNT(bt.tag_id) AS tag_count
FROM BooksDB.dbo.tags AS t
LEFT JOIN BooksDB.dbo.book_tags AS bt
ON t.tag_id = bt.tag_id
WHERE t.tag_name LIKE '%romance%'
GROUP BY t.tag_id, t.tag_name
HAVING COUNT(bt.tag_id) > 100
ORDER BY tag_count DESC
-- Out:
-- (18 rows affected)
-- Total execution time: 00:00:00.364
-- <table><tr><th>tag_id</th><th>tag_name</th><th>tag_count</th></tr><tr><td>26138</td><td>romance</td><td>4251</td></tr><tr><td>8076</td><td>contemporary-romance</td><td>1105</td></tr><tr><td>22983</td><td>paranormal-romance</td><td>840</td></tr><tr><td>1679</td><td>adult-romance</td><td>519</td></tr><tr><td>33045</td><td>ya-romance</td><td>479</td></tr><tr><td>26146</td><td>romance-contemporary</td><td>344</td></tr><tr><td>10824</td><td>erotic-romance</td><td>335</td></tr><tr><td>14527</td><td>historical-romance</td><td>323</td></tr><tr><td>11369</td><td>fantasy-romance</td><td>275</td></tr><tr><td>26163</td><td>romance-paranormal</td><td>219</td></tr><tr><td>21391</td><td>new-adult-romance</td><td>152</td></tr><tr><td>26162</td><td>romance-novels</td><td>128</td></tr><tr><td>29475</td><td>teen-romance</td><td>122</td></tr><tr><td>7677</td><td>college-romance</td><td>117</td></tr><tr><td>33133</td><td>young-adult-romance</td><td>113</td></tr><tr><td>31741</td><td>vampire-romance</td><td>111</td></tr><tr><td>8046</td><td>contemp-romance</td><td>105</td></tr><tr><td>26172</td><td>romance-suspense</td><td>101</td></tr></table>

-- %%
SELECT b.authors, b.title, b.average_rating, bt.tag_id
FROM BooksDB.dbo.books AS b
INNER JOIN BooksDB.dbo.book_tags AS bt
ON bt.goodreads_book_id = b.best_book_id
WHERE bt.tag_id = 26138
ORDER BY average_rating DESC
-- Out:
-- (4119 rows affected)
-- Total execution time: 00:00:01.686
-- <table><tr><th>authors</th><th>title</th><th>average_rating</th><th>tag_id</th></tr><tr><td>Brandon Sanderson</td><td>Words of Radiance (The Stormlight Archive, #2)</td><td>4.77</td><td>26138</td></tr><tr><td>Francine Rivers</td><td>Mark of the Lion Trilogy</td><td>4.76</td><td>26138</td></tr><tr><td>J.K. Rowling</td><td>Harry Potter
niels, #9)</td><td>4.57</td><td>26138</td></tr><tr><td>Amie Kaufman, Jay Kristoff, Marie Lu</td><td>Gemina (The Illuminae Files, #2)</td><td>4.56</td><td>26138</td></tr><tr><td>Veronica Roth</td><td>The Divergent Series 2-Book Collection (Divergent, #1-2)</td><td>4.56</td><td>26138</td></tr><tr><td>George R.R. Martin</td><td>A Storm of Swords: Blood and Gold (A Song of Ice and Fire, #3: Part 2 of 2)</td><td>4.56</td><td>26138</td></tr><tr><td>Brian K. Vaughan, Fiona Staples</td><td>Saga, Vol. 3 (Saga, #3)</td><td>4.56</td><td>26138</td></tr><tr><td>Brandon Sanderson</td><td>Mistborn Trilogy Boxed Set (Mistborn, #1-3)</td><td>4.55</td><td>26138</td></tr><tr><td>Jane Austen</td><td>The Complete Novels</td><td>4.55</td><td>26138</td></tr><tr><td>Jim Butcher</td><td>Skin Game (The Dresden Files, #15)</td><td>4.55</td><td>26138</td></tr><tr><td>Patrick Rothfuss</td><td ...

-- %% [markdown]
-- ### **Summary of event 1:**
--
-- Double Click to edit.

-- %%
-- Event 2 Query
SELECT TOP 100 t.tag_id, t.tag_name, COUNT(bt.tag_id) AS tag_count
FROM BooksDB.dbo.tags AS t
LEFT JOIN BooksDB.dbo.book_tags AS bt
ON t.tag_id = bt.tag_id
WHERE t.tag_name LIKE '%adoption%'
GROUP BY t.tag_id, t.tag_name
ORDER BY tag_count DESC
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.301
-- <table><tr><th>tag_id</th><th>tag_name</th><th>tag_count</th></tr><tr><td>1629</td><td>adoption</td><td>56</td></tr><tr><td>1630</td><td>adoption-and-foster-care</td><td>1</td></tr><tr><td>2547</td><td>animal-adoption</td><td>1</td></tr><tr><td>1631</td><td>adoption-families-foster-homes-love</td><td>1</td></tr></table>

-- %%
SELECT b.authors, b.title, b.average_rating, bt.tag_id
FROM BooksDB.dbo.books AS b
INNER JOIN BooksDB.dbo.book_tags AS bt
ON bt.goodreads_book_id = b.best_book_id
WHERE bt.tag_id = 1629
ORDER BY average_rating DESC
-- Out:
-- (55 rows affected)
-- Total execution time: 00:00:00.137
-- <table><tr><th>authors</th><th>title</th><th>average_rating</th><th>tag_id</th></tr><tr><td>Katie J. Davis, Beth Clark</td><td>Kisses from Katie: A Story of Relentless Love and Redemption</td><td>4.4</td><td>1629</td></tr><tr><td>Lynda Mullaly Hunt</td><td>One for the Murphys</td><td>4.31</td><td>1629</td></tr><tr><td>Mary Beth Chapman, Steven Curtis Chapman</td><td>Choosing to SEE</td><td>4.3</td><td>1629</td></tr><tr><td>Conor Grennan</td><td>Little Princes: One Man's Promise to Bring Home the Lost Children of Nepal</td><td>4.25</td><td>1629</td></tr><tr><td>Janell Cannon</td><td>Stellaluna</td><td>4.22</td><td>1629</td></tr><tr><td>Cathy Glass</td><td>Damaged: The Heartbreaking True Story of a Forgotten Child</td><td>4.2</td><td>1629</td></tr><tr><td>Debbie Macomber</td><td>Summer on Blossom Street (Blossom Street, #6)</td><td>4.19</td><td>1629</td></tr><tr><td>Debbie Macomber</td><td>Twenty Wishes (Blossom Street, #5)</td><td>4.16</td><td>1629</td></tr><tr><td>Holly Goldberg Sloan</td><td>Counting by 7s</td><td>4.16</td><td>1629</td></tr><tr><td>Christina Baker